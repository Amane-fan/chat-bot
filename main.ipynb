# %%
from langchain import ChatOpenAI, ChatPromptTemplate, SystemMessage, HumanMessage
from langchain_core.prompts import PromptTemplate
PromptTemplate.from_messages(
    [
        ("system", "你是一个天气查询助手"),
        ("human", "请告诉我{province}的天气")
    ]
)
